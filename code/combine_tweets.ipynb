# %%
import pandas as pd
import os



pd.options.display.max_columns = 40

# %%
tweets = os.listdir("../data/tweets/")
files = [csv for csv in tweets if csv[-4:] == '.csv']

# %%
# combine all CSVs into one DF
dfs = []
for file in files:
    dfs.append(pd.read_csv(f"../data/tweets/{file}"))

df_t = pd.concat(dfs)

df_t.head(3)
# Out:
#                     id      conversation_id               created_at  \
# 0  1313630113934737411  1313585320353509381  2020-10-06 23:59:59 UTC
# 1  1313630113821581312  1312053113952645129  2020-10-06 23:59:59 UTC
# 2  1313630112789803011  1313581778502930432  2020-10-06 23:59:59 UTC
#
#          date      time  timezone              user_id         username  \
# 0  2020-10-06  23:59:59         0            481962653      sully_lilly
# 1  2020-10-06  23:59:59         0  1299543389092884480         nutzwhat
# 2  2020-10-06  23:59:59         0  1156541146287542272  carolwo53195499
#
#              name place                                              tweet  \
# 0     lilly&sully   NaN  @JoeBiden 47 years and now you are ready to do...
# 1          Zendog   NaN  @Astraea_Muse @DontBanMeBro7 @RonColeman @JoeB...
# 2  Carol Woodward   NaN  @ElTomatill0 @jimsciutto @JoeBiden He has said...
#
#   language mentions urls photos  replies_count  retweets_count  likes_count  \
# 0       en       []   []     []              0               1            2
# 1       en       []   []     []              0               0            0
# 2       en       []   []     []              1               0            1
#
#             hashtags cashtags  \
# 0  ['draintheswamp']       []
# 1                 []       []
# 2                 []       []
#
#                                                 link  retweet quote_url  \
# 0  https://twitter.com/sully_lilly/status/1313630...    False       NaN
# 1  https://twitter.com/NutzWhat/status/1313630113...    False       NaN
# 2  https://twitter.com/CarolWo53195499/status/131...    False       NaN
#
#    video thumbnail  near  geo  source  user_rt_id  user_rt  retweet_id  \
# 0      0       NaN   NaN  NaN     NaN         NaN      NaN         NaN
# 1      0       NaN   NaN  NaN     NaN         NaN      NaN         NaN
# 2      0       NaN   NaN  NaN     NaN         NaN      NaN         NaN
#
#                                             reply_to  retweet_date  translate  \
# 0  [{'screen_name': 'JoeBiden', 'name': 'Joe Bide...           NaN        NaN
# 1  [{'screen_name': 'Astraea_Muse', 'name': 'Taki...           NaN        NaN
# 2  [{'screen_name': 'ElTomatill0', 'name': 'Tom 🌊...           NaN        NaN
#
#    trans_src  trans_dest
# 0        NaN         NaN
# 1        NaN         NaN
# 2        NaN         NaN

# %%
df_t.tweet.iloc[29843]
# Out:
# '@smitaprakash For Trump, it is always China First! #LiarInChief   MAGA hats and all Trumps items are #MadeInChina  BIDEN hats are #MadeInTheUSA  https://t.co/0kN42Ru7pI'

# %%
df_t.drop_duplicates(subset='id', inplace=True)

# %%
df_t.shape
# Out:
# (318646, 36)
